# %% [markdown]
# # Flights Data Exploration Challenge
#
# In this challenge, you'll explore a real-world dataset containing flights data from the US Department of Transportation.
#
# Let's start by loading and viewing the data.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

df_flights = pd.read_csv('data/flights.csv')
df_flights.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 0  2013      9          16          1      DL            15304
# 1  2013      9          23          1      WN            14122
# 2  2013      9           7          6      AS            14747
# 3  2013      7          22          1      OO            13930
# 4  2013      5          16          4      DL            13931
#
#               OriginAirportName  OriginCity OriginState  DestAirportID  \
# 0           Tampa International       Tampa          FL          12478
# 1      Pittsburgh International  Pittsburgh          PA          13232
# 2  Seattle/Tacoma International     Seattle          WA          11278
# 3  Chicago O'Hare International     Chicago          IL          11042
# 4         Norfolk International     Norfolk          VA          10397
#
#                             DestAirportName    DestCity DestState  CRSDepTime  \
# ...

# %% [markdown]
# The dataset contains observations of US domestic flights in 2013, and consists of the following fields:
#
# - **Year**: The year of the flight (all records are from 2013)
# - **Month**: The month of the flight
# - **DayofMonth**: The day of the month on which the flight departed
# - **DayOfWeek**: The day of the week on which the flight departed - from 1 (Monday) to 7 (Sunday)
# - **Carrier**: The two-letter abbreviation for the airline.
# - **OriginAirportID**: A unique numeric identifier for the departure aiport
# - **OriginAirportName**: The full name of the departure airport
# - **OriginCity**: The departure airport city
# - **OriginState**: The departure airport state
# - **DestAirportID**: A unique numeric identifier for the destination aiport
# - **DestAirportName**: The full name of the destination airport
# - **DestCity**: The destination airport city
# - **DestState**: The destination airport state
# - **CRSDepTime**: The scheduled departure time
# - **DepDelay**: The number of minutes departure was delayed (flight that left ahead of schedule have a negative value)
# - **DepDelay15**: A binary indicator that departure was delayed by more than 15 minutes (and therefore considered "late")
# - **CRSArrTime**: The scheduled arrival time
# - **ArrDelay**: The number of minutes arrival was delayed (flight that arrived ahead of schedule have a negative value)
# - **ArrDelay15**: A binary indicator that arrival was delayed by more than 15 minutes (and therefore considered "late")
# - **Cancelled**: A binary indicator that the flight was cancelled
#
# Your challenge is to explore the flight data to analyze possible factors that affect delays in departure or arrival of a flight.
#
# 1. Start by cleaning the data.
#     - Identify any null or missing data, and impute appropriate replacement values.
#     - Identify and eliminate any outliers in the **DepDelay** and **ArrDelay** columns.
# 2. Explore the cleaned data.
#     - View summary statistics for the numeric fields in the dataset.
#     - Determine the distribution of the **DepDelay** and **ArrDelay** columns.
#     - Use statistics, aggregate functions, and visualizations to answer the following questions:
#         - *What are the average (mean) departure and arrival delays?*
#         - *How do the carriers compare in terms of arrival delay performance?*
#         - *Is there a noticable difference in arrival delays for different days of the week?*
#         - *Which departure airport has the highest average departure delay?*
#         - *Do **late** departures tend to result in longer arrival delays than on-time departures?*
#         - *Which route (from origin airport to destination airport) has the most **late** arrivals?*
#         - *Which route has the highest average arrival delay?*
#
# Add markdown and code cells as required to create your solution.
#
# > **Note**: There is no single "correct" solution. A sample solution is provided in [01 - Flights Challenge.ipynb](01%20-%20Flights%20Solution.ipynb).

# %%
# Your code to explore the data
df_flights.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek  OriginAirportID  \
# count  271940.0  271940.000000  271940.000000  271940.000000    271940.000000
# mean     2013.0       6.978514      15.814775       3.899316     12744.899584
# std         0.0       1.982431       8.799033       1.987219      1501.199773
# min      2013.0       4.000000       1.000000       1.000000     10140.000000
# 25%      2013.0       5.000000       8.000000       2.000000     11292.000000
# 50%      2013.0       7.000000      16.000000       4.000000     12892.000000
# 75%      2013.0       9.000000      23.000000       6.000000     14057.000000
# max      2013.0      10.000000      31.000000       7.000000     15376.000000
#
#        DestAirportID     CRSDepTime       DepDelay       DepDel15  \
# count  271940.000000  271940.000000  271940.000000  269179.000000
# mean    12739.136493    1325.498713      10.350449       0.201134
# std      1502.569949     470.748546      35.673710       0.400849
# ...

# %%
# Identify number of nulls
df_flights.isnull().sum()

# We can see that all of the nulls occur in the DepDel15 column - let's see what kind of flights have null in this category
df_flights_nullsOnly = df_flights[df_flights.isnull().any(axis=1)]
df_flights_nullsOnly
# Out:
#         Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 171     2013      4          18          4      DL            10397
# 359     2013      5          22          3      OO            11433
# 429     2013      7           3          3      MQ            13851
# 545     2013      4          13          6      FL            14524
# 554     2013      5           8          3      EV            12953
# ...      ...    ...         ...        ...     ...              ...
# 271410  2013      8           5          1      WN            14831
# 271607  2013      6          18          2      EV            14100
# 271634  2013      5           8          3      AA            11298
# 271671  2013     10           8          2      WN            12892
# 271885  2013      5          15          3      US            14771
#
#                                OriginAirportName         OriginCity  \
# 171     Hartsfield-Jackson Atlanta International            Atlanta
# ...

# %%
# It looks like all the flights with null values in DepDel15 might have been cancelled flights - lets verify this
percentage_cancelled_ofNulls = (df_flights_nullsOnly['Cancelled'].sum() / len(df_flights_nullsOnly)) * 100
print(f"Percentage of NaN rows that were cancelled flights: {percentage_cancelled_ofNulls:.2f}%")
# Out:
# Percentage of NaN rows that were cancelled flights: 100.00%

# %%
# So if all the nul lvalues are just cancelled flights, and it seems like the dataset dealt with cancelled flights by using a value of 1 for ArrDel15
#   why don't we apply the same logic to the DepDelay15 column
df_flights.DepDel15 = df_flights.DepDel15.fillna(1)
df_flights.DepDel15.isnull().sum()
# Out:
# np.int64(0)

# %%
# Let's see what it looks like now
df_flights.describe()
# Out:
#            Year          Month     DayofMonth      DayOfWeek  OriginAirportID  \
# count  271940.0  271940.000000  271940.000000  271940.000000    271940.000000
# mean     2013.0       6.978514      15.814775       3.899316     12744.899584
# std         0.0       1.982431       8.799033       1.987219      1501.199773
# min      2013.0       4.000000       1.000000       1.000000     10140.000000
# 25%      2013.0       5.000000       8.000000       2.000000     11292.000000
# 50%      2013.0       7.000000      16.000000       4.000000     12892.000000
# 75%      2013.0       9.000000      23.000000       6.000000     14057.000000
# max      2013.0      10.000000      31.000000       7.000000     15376.000000
#
#        DestAirportID     CRSDepTime       DepDelay       DepDel15  \
# count  271940.000000  271940.000000  271940.000000  271940.000000
# mean    12739.136493    1325.498713      10.350449       0.209245
# std      1502.569949     470.748546      35.673710       0.406770
# ...

# %%
# Now let's check for outliers in the DepDelay and ArrDelay columns

# Create a function that we can re-use for showing distribution
def show_distribution(var_data):
    from matplotlib import pyplot as plt

    # Get statistics
    min_val = var_data.min()
    max_val = var_data.max()
    mean_val = var_data.mean()
    med_val = var_data.median()
    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                            mean_val,
                                                                                            med_val,
                                                                                            mod_val,
                                                                                            max_val))

    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize = (10,4))

    # Plot the histogram   
    ax[0].hist(var_data)
    ax[0].set_ylabel('Frequency')

    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

    # Plot the boxplot   
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')

    # Add a title to the Figure
    fig.suptitle('Data Distribution')

    # Show the figure
    fig.show()

# %%
show_distribution(df_flights['DepDelay'])

# %%
show_distribution(df_flights['ArrDelay'])

# %%
# Let's remove the outliers at the top of the dataset where it looks like they mostly reside
# 3 Std away from the mean for the columns can be calculated with the below function

def upper_lower(column):
  # Calculate the mean and standard deviation
  mean = df_flights[column].mean()
  std_dev = df_flights[column].std()

  # Calculate the lower and upper bounds (3 standard deviations away)
  lower_bound = mean - (3 * std_dev)
  upper_bound = mean + (3 * std_dev)

  print(f"For column '{column}':")
  print(f"Mean: {mean:.2f}")
  print(f"3 standard deviations away -> Lower bound: {lower_bound:.2f}, Upper bound: {upper_bound:.2f}")
  
upper_lower('ArrDelay')
upper_lower('DepDelay')
# Out:
# For column 'ArrDelay':
# Mean: 6.50
# 3 standard deviations away -> Lower bound: -108.19, Upper bound: 121.19
# For column 'DepDelay':
# Mean: 10.35
# 3 standard deviations away -> Lower bound: -96.67, Upper bound: 117.37

# %%
upper_limit_arrDelay = 121.19
lower_limit_arrDelay = -108.19
upper_limit_depDelay = 117.37
lower_limit_depDelay = -96.67

filtered_df_flights = df_flights[(df_flights['ArrDelay'] >= lower_limit_arrDelay) & 
                                 (df_flights['ArrDelay'] <= upper_limit_arrDelay)]
print("Outliers from ArrDelay filtered!")
show_distribution(filtered_df_flights['ArrDelay'])

# Here we see a much better distribution of the data without the outliers in ArrDelay
# We can do the same for DepDelay now

filtered_df_flights = filtered_df_flights[(filtered_df_flights['DepDelay'] >= lower_limit_depDelay) &
                                          (filtered_df_flights['DepDelay'] <= upper_limit_depDelay)]
print("Outliers from DepDelay filtered!")
show_distribution(filtered_df_flights['DepDelay'])

# %%
# Now we can explore the clean data
# Summary stats

print('The mean for ArrDelay: {:.2f}\nThe mean for DepDelay: {:.2f}'.format(filtered_df_flights['ArrDelay'].mean(), filtered_df_flights['DepDelay'].mean()))

filtered_df_flights[['ArrDelay', 'DepDelay']].describe()

# %%
# Let's find the average arrival delay per carrier
avg_delay_per_carrier = filtered_df_flights.groupby(filtered_df_flights.Carrier)['ArrDelay'].mean()
avg_delay_per_carrier = avg_delay_per_carrier.sort_values(ascending=False)

plt.bar(x = avg_delay_per_carrier.index, height=avg_delay_per_carrier, color = 'teal')
plt.title("Avg Delayed Arrival Time per Carrier")
plt.xlabel("Flight Carrier")
plt.ylabel("Mean Delayed Arrival Time")

plt.show()

# Can conclude Carrier F9 has the most delay time on average

# %%
# Let's find the average arrival delay per day
avg_delay_per_day = filtered_df_flights.groupby(filtered_df_flights['DayOfWeek'])['ArrDelay'].mean()
avg_delay_per_day = avg_delay_per_day.sort_values()

plt.bar(x = avg_delay_per_day.index, height=avg_delay_per_day, color = 'gold')
plt.title("Avg Delayed Arrival Time per Day Of Week")
plt.xlabel("Day Of Week")
plt.ylabel("Mean Delayed Arrival Time")

new_ticks = ['Mon', 'Tues', 'Weds', 'Thurs', 'Fri', 'Sat', 'Sun']
plt.xticks(ticks=[1,2,3,4,5,6,7], labels=new_ticks)

plt.show()

# We can see that the days Friday and Thursday are the worst in terms of delayed arrival times
# for flights

# %%
avg_depDelay_per_airport = filtered_df_flights.groupby(filtered_df_flights['DestAirportName'])['DepDelay'].mean()
avg_depDelay_per_airport = avg_depDelay_per_airport.sort_values(ascending=False)

plt.figure(figsize=(12,10))

plt.bar(x = avg_depDelay_per_airport.index, height=avg_depDelay_per_airport, color = 'teal')
plt.title("Avg Delayed Departure Time per Carrier")
plt.xlabel("Flight Carrier")
plt.ylabel("Mean Delayed Departure Time")
plt.xticks(rotation=90)

plt.show()

# We can see that the highest average departure delay comes from the airport: San Francisco Intl.

# %%
# *Do late departures tend to result in longer arrival delays than on-time departures?*
# Let's answer this by making a side by side bar bar chart

late_departures = filtered_df_flights[filtered_df_flights['DepDel15'] == 1]
early_departures = filtered_df_flights[filtered_df_flights['DepDel15'] == 0]

late_departures_avg_arrDelay = late_departures['ArrDelay'].mean()
early_departures_avg_arrDelay = early_departures['ArrDelay'].mean()

plt.Figure(figsize=(12,10))
plt.bar(x = ['Late Departures', 'On-time Departures'], 
        height = [late_departures_avg_arrDelay, early_departures_avg_arrDelay], 
        width = 0.5, color = 'purple')
plt.ylabel("Avg Delay In Arrival Time At Destination")
plt.show()

# This plot shows that there is definitely a corelation between late departures and delays in arriving
# at the destination airport
